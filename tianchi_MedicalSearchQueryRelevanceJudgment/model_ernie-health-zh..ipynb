# %%
import torch
from transformers import AutoModel, AutoTokenizer
import torch.nn as nn
import torch.optim as optim
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from colorama import Fore, Style
from transformers import logging

from utils import (set_seed, read_data, get_collate_fn, evaluate, predict)

logging.set_verbosity_error()

# %%
USE_AUGMENT = False

SEED = 2022
set_seed(SEED)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
train_data = read_data('datasets/KUAKE-QQR_train.json')
valid_data = read_data('datasets/KUAKE-QQR_dev.json')

if USE_AUGMENT:  # 是否开启数据增强
    augment_data = pd.read_csv('extra_data/augment_data.csv')
    all_data = pd.concat([train_data, valid_data, augment_data], axis=0)
    all_data = all_data.drop_duplicates()
else:
    all_data = pd.concat([train_data, valid_data], axis=0)

# %%
model_ckpt = "nghuyong/ernie-health-zh"
token = AutoTokenizer.from_pretrained(model_ckpt)
print(token.model_input_names)
# Out:
# ['input_ids', 'token_type_ids', 'attention_mask']

# %%
class CustomModel(nn.Module):
    """下游训练任务模型"""

    def __init__(self, pretrained_model_name):
        super(CustomModel, self).__init__()
        self.pretrained = AutoModel.from_pretrained(pretrained_model_name)
        self.fc = torch.nn.Linear(self.pretrained.config.hidden_size, 3)

    def forward(self, input_ids, attention_mask, token_type_ids):
        out = self.pretrained(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        # output.shape=[batch_size, class_num]
        out = self.fc(out[1])
        out = out.softmax(dim=1)
        return out

# %%
# 模型训练
def train_and_evaluate(model, dataloader_train, dataloader_valid, best, criterion, optimizer, scheduler_lr=None,
                       device=torch.device('cpu')):
    model.train()

    for idx, (input_ids, attention_mask, token_type_ids, labels) in enumerate(dataloader_train, start=1):
        # 数据设备切换
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        token_type_ids = token_type_ids.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        out = model(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)

        loss = criterion(out, labels)  # 每个step的损失值
        loss.backward()
        optimizer.step()
        if scheduler_lr is not None:
            scheduler_lr.step()

        if idx % 20 == 0:
            valid_acc = evaluate(model, dataloader_valid, device)
            train_step_acc = accuracy_score(labels.cpu().numpy(), torch.argmax(out.cpu(), dim=1).numpy())  # 评估指标
            if best[1] < valid_acc:
                best.pop()
                best.append(valid_acc)
                torch.save(model.state_dict(), 'models/save_model_{}.pkl'.format(best[0]))
                print('| step {:5d} | loss {:9.6f} | train_step_acc {:9.6f} | valid_acc {:9.6f} |'.format(idx,
                                                                                                          loss.item(),
                                                                                                          train_step_acc,
                                                                                                          valid_acc))

# %%
skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

for fold, (trn_ind, val_ind) in enumerate(skfold.split(all_data, all_data['label'].values)):
    print(Fore.RED + '#' * 50 + str(fold) + '#' * 50)
    print(Style.RESET_ALL, end='')
    train_data, valid_data = all_data.iloc[trn_ind].values.tolist(), all_data.iloc[val_ind].values.tolist()
    dataloader_train = torch.utils.data.DataLoader(train_data,
                                                   shuffle=True,
                                                   batch_size=64,
                                                   collate_fn=get_collate_fn(token))
    dataloader_valid = torch.utils.data.DataLoader(valid_data,
                                                   batch_size=64,
                                                   collate_fn=get_collate_fn(token))
    # *****************************************************************************
    model = CustomModel(model_ckpt)
    model = model.to(device)

    optimizer_adamw = optim.AdamW(model.parameters(), lr=1e-5)
    criterion_cross_entropy = torch.nn.CrossEntropyLoss()
    # *****************************************************************************
    best_acc_list = [fold, 0.0]
    for epoch in range(5):
        print('-' * 40 + str(epoch) + '-' * 40)
        train_and_evaluate(model, dataloader_train, dataloader_valid, best_acc_list, criterion_cross_entropy,
                           optimizer_adamw, None, device)
    print(best_acc_list)
# Out:
# ##################################################0##################################################
# ----------------------------------------0----------------------------------------
# | step    20 | loss  1.002134 | train_step_acc  0.593750 | valid_acc  0.599699 |
# | step    80 | loss  0.836205 | train_step_acc  0.718750 | valid_acc  0.718072 |
# | step   100 | loss  0.847561 | train_step_acc  0.703125 | valid_acc  0.731325 |
# | step   120 | loss  0.801129 | train_step_acc  0.750000 | valid_acc  0.757831 |
# | step   140 | loss  0.802962 | train_step_acc  0.765625 | valid_acc  0.796988 |
# | step   160 | loss  0.731436 | train_step_acc  0.828125 | valid_acc  0.810542 |
# | step   180 | loss  0.723662 | train_step_acc  0.828125 | valid_acc  0.816265 |
# | step   200 | loss  0.762165 | train_step_acc  0.796875 | valid_acc  0.825000 |
# ----------------------------------------1----------------------------------------
# | step    20 | loss  0.774433 | train_step_acc  0.750000 | valid_acc  0.832229 |
# | step    40 | loss  0.673212 | train_step_acc  0.890625 | valid_acc  0.833735 |
# | step    60 | loss  0.674778 | train_step_acc  0.875000 | valid_acc  0.838554 |
# | step    80 | loss  0.719403 | train_step_acc  0.828125 | valid_acc  0.846687 |
# | step   120 | loss  0.717059 | train_step_acc  0.828125 | valid_acc  0.848193 |
# ----------------------------------------2----------------------------------------
# | step    20 | loss  0.668014 | train_step_acc  0.875000 | valid_acc  0.848795 |
# | step    60 | loss  0.739782 | train_step_acc  0.796875 | valid_acc  0.856627 |
# | step   120 | loss  0.708545 | train_step_acc  0.843750 | valid_acc  0.859036 |
# | step   160 | loss  0.695157 | train_step_acc  0.859375 | valid_acc  0.863253 |
# | step   200 | loss  0.659733 | train_step_acc  0.890625 | valid_acc  0.866265 |
# ----------------------------------------3----------------------------------------
# | step    60 | loss  0.649432 | train_step_acc  0.906250 | valid_acc  0.867470 |
# | step    80 | loss  0.619244 | train_step_acc  0.937500 | valid_acc  0.867771 |
# | step   100 | loss  0.700341 | train_step_acc  0.859375 | valid_acc  0.868976 |
# | step   120 | loss  0.591208 | train_step_acc  0.953125 | valid_acc  0.870181 |
# | step   180 | loss  0.687263 | train_step_acc  0.875000 | valid_acc  0.870482 |
# ----------------------------------------4----------------------------------------
# | step    20 | loss  0.668215 | train_step_acc  0.875000 | valid_acc  0.873193 |
# | step   180 | loss  0.643019 | train_step_acc  0.906250 | valid_acc  0.875904 |
# [0, 0.8759036144578313]
# ##################################################1##################################################
# ----------------------------------------0----------------------------------------
# | step    20 | loss  0.974573 | train_step_acc  0.640625 | valid_acc  0.599699 |
# | step    60 | loss  0.841886 | train_step_acc  0.671875 | valid_acc  0.618976 |
# | step    80 | loss  0.810835 | train_step_acc  0.750000 | valid_acc  0.708133 |
# | step   100 | loss  0.770526 | train_step_acc  0.781250 | valid_acc  0.723494 |
# | step   120 | loss  0.777431 | train_step_acc  0.765625 | valid_acc  0.731928 |
# | step   140 | loss  0.767620 | train_step_acc  0.781250 | valid_acc  0.733434 |
# | step   160 | loss  0.779297 | train_step_acc  0.765625 | valid_acc  0.734639 |
# | step   180 | loss  0.800389 | train_step_acc  0.734375 | valid_acc  0.779217 |
# ----------------------------------------1----------------------------------------
# | step    20 | loss  0.833408 | train_step_acc  0.718750 | valid_acc  0.800301 |
# | step    60 | loss  0.672986 | train_step_acc  0.890625 | valid_acc  0.819880 |
# | step    80 | loss  0.735986 | train_step_acc  0.796875 | valid_acc  0.820482 |
# | step   100 | loss  0.757782 | train_step_acc  0.781250 | valid_acc  0.828916 |
# | step   140 | loss  0.712709 | train_step_acc  0.843750 | valid_acc  0.830723 |
# | step   180 | loss  0.676783 | train_step_acc  0.875000 | valid_acc  0.835241 |
# | step   200 | loss  0.711174 | train_step_acc  0.828125 | valid_acc  0.842169 |
# ----------------------------------------2----------------------------------------
# | step   180 | loss  0.632027 | train_step_acc  0.921875 | valid_acc  0.844578 |
# | step   200 | loss  0.738090 | train_step_acc  0.812500 | valid_acc  0.847892 |
# ----------------------------------------3----------------------------------------
# | step    60 | loss  0.663576 | train_step_acc  0.890625 | valid_acc  0.849699 |
# | step   140 | loss  0.639858 | train_step_acc  0.906250 | valid_acc  0.854217 |
# ----------------------------------------4----------------------------------------
# | step    40 | loss  0.717896 | train_step_acc  0.828125 | valid_acc  0.855723 |
# | step    60 | loss  0.700166 | train_step_acc  0.843750 | valid_acc  0.857530 |
# | step    80 | loss  0.663886 | train_step_acc  0.890625 | valid_acc  0.862048 |
# | step   120 | loss  0.644968 | train_step_acc  0.906250 | valid_acc  0.862651 |
# [1, 0.8626506024096385]
# ##################################################2##################################################
# ----------------------------------------0----------------------------------------
# | step    20 | loss  0.995902 | train_step_acc  0.593750 | valid_acc  0.599699 |
# | step    60 | loss  0.924986 | train_step_acc  0.546875 | valid_acc  0.677108 |
# | step    80 | loss  0.885006 | train_step_acc  0.656250 | valid_acc  0.715663 |
# | step   100 | loss  0.868219 | train_step_acc  0.640625 | valid_acc  0.734337 |
# | step   120 | loss  0.785394 | train_step_acc  0.765625 | valid_acc  0.739157 |
# | step   140 | loss  0.842051 | train_step_acc  0.750000 | valid_acc  0.784036 |
# | step   160 | loss  0.726584 | train_step_acc  0.843750 | valid_acc  0.801506 |
# | step   180 | loss  0.764195 | train_step_acc  0.765625 | valid_acc  0.805723 |
# | step   200 | loss  0.712278 | train_step_acc  0.828125 | valid_acc  0.814759 |
# ----------------------------------------1----------------------------------------
# | step    40 | loss  0.720236 | train_step_acc  0.828125 | valid_acc  0.831024 |
# | step    80 | loss  0.662256 | train_step_acc  0.890625 | valid_acc  0.831928 |
# | step   100 | loss  0.670146 | train_step_acc  0.875000 | valid_acc  0.834337 |
# | step   140 | loss  0.731353 | train_step_acc  0.812500 | valid_acc  0.837048 |
# | step   160 | loss  0.677579 | train_step_acc  0.875000 | valid_acc  0.840361 |
# ----------------------------------------2----------------------------------------
# | step    40 | loss  0.707155 | train_step_acc  0.843750 | valid_acc  0.845482 |
# | step    60 | loss  0.730167 | train_step_acc  0.843750 | valid_acc  0.848494 |
# | step   120 | loss  0.694845 | train_step_acc  0.843750 | valid_acc  0.850000 |
# | step   160 | loss  0.643418 | train_step_acc  0.906250 | valid_acc  0.856024 |
# | step   200 | loss  0.671520 | train_step_acc  0.875000 | valid_acc  0.856325 |
# ----------------------------------------3----------------------------------------
# | step    40 | loss  0.577406 | train_step_acc  0.968750 | valid_acc  0.862349 |
# | step    80 | loss  0.672210 | train_step_acc  0.875000 | valid_acc  0.863855 |
# | step   160 | loss  0.632328 | train_step_acc  0.921875 | valid_acc  0.864759 |
# ----------------------------------------4----------------------------------------
# | step    80 | loss  0.642462 | train_step_acc  0.906250 | valid_acc  0.865060 |
# [2, 0.8650602409638555]
# ##################################################3##################################################
# ----------------------------------------0----------------------------------------
# | step    20 | loss  0.985790 | train_step_acc  0.609375 | valid_acc  0.599398 |
# | step    60 | loss  0.875462 | train_step_acc  0.687500 | valid_acc  0.672590 |
# | step    80 | loss  0.930154 | train_step_acc  0.609375 | valid_acc  0.713554 |
# | step   100 | loss  0.781688 | train_step_acc  0.765625 | valid_acc  0.726205 |
# | step   120 | loss  0.752230 | train_step_acc  0.796875 | valid_acc  0.738554 |
# | step   140 | loss  0.696837 | train_step_acc  0.875000 | valid_acc  0.787952 |
# | step   160 | loss  0.792823 | train_step_acc  0.765625 | valid_acc  0.793373 |
# | step   180 | loss  0.717089 | train_step_acc  0.843750 | valid_acc  0.811145 |
# ----------------------------------------1----------------------------------------
# | step    20 | loss  0.739575 | train_step_acc  0.796875 | valid_acc  0.813554 |
# | step    40 | loss  0.726855 | train_step_acc  0.812500 | valid_acc  0.816867 |
# | step    60 | loss  0.705678 | train_step_acc  0.843750 | valid_acc  0.818675 |
# | step    80 | loss  0.721325 | train_step_acc  0.828125 | valid_acc  0.823193 |
# | step   100 | loss  0.759160 | train_step_acc  0.796875 | valid_acc  0.824699 |
# | step   120 | loss  0.786696 | train_step_acc  0.750000 | valid_acc  0.829518 |
# | step   160 | loss  0.679417 | train_step_acc  0.875000 | valid_acc  0.832229 |
# | step   180 | loss  0.686057 | train_step_acc  0.875000 | valid_acc  0.835843 |
# | step   200 | loss  0.699350 | train_step_acc  0.859375 | valid_acc  0.837952 |
# ----------------------------------------2----------------------------------------
# | step    40 | loss  0.685765 | train_step_acc  0.875000 | valid_acc  0.838554 |
# | step    60 | loss  0.713108 | train_step_acc  0.828125 | valid_acc  0.839759 |
# | step   100 | loss  0.692363 | train_step_acc  0.843750 | valid_acc  0.846687 |
# | step   120 | loss  0.646287 | train_step_acc  0.906250 | valid_acc  0.847892 |
# | step   140 | loss  0.630762 | train_step_acc  0.921875 | valid_acc  0.856325 |
# | step   200 | loss  0.693058 | train_step_acc  0.859375 | valid_acc  0.856627 |
# ----------------------------------------3----------------------------------------
# | step    60 | loss  0.662339 | train_step_acc  0.890625 | valid_acc  0.857530 |
# | step   120 | loss  0.660560 | train_step_acc  0.890625 | valid_acc  0.857831 |
# ----------------------------------------4----------------------------------------
# | step    60 | loss  0.701424 | train_step_acc  0.828125 | valid_acc  0.858735 |
# | step    80 | loss  0.659416 | train_step_acc  0.890625 | valid_acc  0.861747 |
# | step   100 | loss  0.602392 | train_step_acc  0.953125 | valid_acc  0.862048 |
# | step   200 | loss  0.665519 | train_step_acc  0.890625 | valid_acc  0.865060 |
# [3, 0.8650602409638555]
# ##################################################4##################################################
# ----------------------------------------0----------------------------------------
# | step    20 | loss  0.987172 | train_step_acc  0.656250 | valid_acc  0.599398 |
# | step    60 | loss  0.864635 | train_step_acc  0.640625 | valid_acc  0.618675 |
# | step    80 | loss  0.846292 | train_step_acc  0.703125 | valid_acc  0.718373 |
# | step   100 | loss  0.757115 | train_step_acc  0.796875 | valid_acc  0.723795 |
# | step   120 | loss  0.761918 | train_step_acc  0.765625 | valid_acc  0.733133 |
# | step   140 | loss  0.752499 | train_step_acc  0.828125 | valid_acc  0.763253 |
# | step   160 | loss  0.790291 | train_step_acc  0.765625 | valid_acc  0.814157 |
# | step   180 | loss  0.780455 | train_step_acc  0.781250 | valid_acc  0.818072 |
# | step   200 | loss  0.769317 | train_step_acc  0.781250 | valid_acc  0.828916 |
# ----------------------------------------1----------------------------------------
# | step    60 | loss  0.617154 | train_step_acc  0.937500 | valid_acc  0.835542 |
# | step   100 | loss  0.762794 | train_step_acc  0.781250 | valid_acc  0.839759 |
# | step   140 | loss  0.687207 | train_step_acc  0.859375 | valid_acc  0.845181 |
# | step   180 | loss  0.760729 | train_step_acc  0.781250 | valid_acc  0.847289 |
# | step   200 | loss  0.757787 | train_step_acc  0.796875 | valid_acc  0.850904 |
# ----------------------------------------2----------------------------------------
# | step   100 | loss  0.684337 | train_step_acc  0.859375 | valid_acc  0.853313 |
# | step   140 | loss  0.658862 | train_step_acc  0.890625 | valid_acc  0.860241 |
# ----------------------------------------3----------------------------------------
# | step    60 | loss  0.616569 | train_step_acc  0.937500 | valid_acc  0.861145 |
# | step   100 | loss  0.655587 | train_step_acc  0.890625 | valid_acc  0.865060 |
# ----------------------------------------4----------------------------------------
# | step    60 | loss  0.643083 | train_step_acc  0.906250 | valid_acc  0.866265 |
# [4, 0.8662650602409638]

# %%
k_fold_predict = np.zeros([1596, 3])

for i in range(5):
    model_predict = CustomModel(model_ckpt)
    model_predict.load_state_dict(torch.load('models/save_model_{}.pkl'.format(i)))
    model_predict = model_predict.to(device)
    result_i = predict('datasets/KUAKE-QQR_test.json', token, model_predict, device)
    k_fold_predict += (result_i / 5)

# %%
joblib.dump(k_fold_predict, 'predict/erniehealth_base.pkl')
# Out:
# ['predict/erniehealth_base.pkl']
